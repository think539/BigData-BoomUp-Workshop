# %%
import pandas as pd
mbti_train = pd.read_csv('MBTI_train.csv', header=None)
mbti_test = pd.read_csv('MBTI_test.csv', header=None)

# %%
mbti_train.columns = ['mbti', 'words']

# %%
mbti_train
# Out:
#        mbti                                              words
# 0      INTP  say process model list like subscriber channel...
# 1      INFJ  upon much manipulate retail finish like sacrif...
# 2      INFJ  fit yes certain bff social feel goal go know n...
# 3      INTJ  complete love within someone ideal joke solvea...
# 4      ENTJ  public strictly thing person x question person...
# ...     ...                                                ...
# 74352  INTP  get consequence process life back kind great b...
# 74353  ENFP  mundane really right vibe natural u conscious ...
# 74354  INFP  diva message remember practical lot absorb tel...
# 74355  INTJ  increase impressive group make recognize get a...
# 74356  ENTJ  restaurant negative entj resent people sing ma...
#
# [74357 rows x 2 columns]

# %% [markdown]
# # mbti E

# %%
mbti_train['E'] = [0]*74357
mbti_train
# Out:
#        mbti                                              words  E
# 0      INTP  say process model list like subscriber channel...  0
# 1      INFJ  upon much manipulate retail finish like sacrif...  0
# 2      INFJ  fit yes certain bff social feel goal go know n...  0
# 3      INTJ  complete love within someone ideal joke solvea...  0
# 4      ENTJ  public strictly thing person x question person...  0
# ...     ...                                                ... ..
# 74352  INTP  get consequence process life back kind great b...  0
# 74353  ENFP  mundane really right vibe natural u conscious ...  0
# 74354  INFP  diva message remember practical lot absorb tel...  0
# 74355  INTJ  increase impressive group make recognize get a...  0
# 74356  ENTJ  restaurant negative entj resent people sing ma...  0
#
# [74357 rows x 3 columns]

# %%
mbti_train['mbti'][0][0]
# Out:
# 'I'

# %%
for i in range(74357):
  if mbti_train['mbti'][i][0] == 'E':
    mbti_train['E'][i] = 1
mbti_train
# Out:
# <ipython-input-7-696d385226a5>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mbti_train['E'][i] = 1
#        mbti                                              words  E
# 0      INTP  say process model list like subscriber channel...  0
# 1      INFJ  upon much manipulate retail finish like sacrif...  0
# 2      INFJ  fit yes certain bff social feel goal go know n...  0
# 3      INTJ  complete love within someone ideal joke solvea...  0
# 4      ENTJ  public strictly thing person x question person...  1
# ...     ...                                                ... ..
# 74352  INTP  get consequence process life back kind great b...  0
# 74353  ENFP  mundane really right vibe natural u conscious ...  1
# 74354  INFP  diva message remember practical lot absorb tel...  0
# ...

# %%
mbti_e_train = mbti_train.loc[:,['words','E']]

# %%
mbti_e_train
# Out:
#                                                    words  E
# 0      say process model list like subscriber channel...  0
# 1      upon much manipulate retail finish like sacrif...  0
# 2      fit yes certain bff social feel goal go know n...  0
# 3      complete love within someone ideal joke solvea...  0
# 4      public strictly thing person x question person...  1
# ...                                                  ... ..
# 74352  get consequence process life back kind great b...  0
# 74353  mundane really right vibe natural u conscious ...  1
# 74354  diva message remember practical lot absorb tel...  0
# 74355  increase impressive group make recognize get a...  0
# 74356  restaurant negative entj resent people sing ma...  1
#
# [74357 rows x 2 columns]

# %%
count = 0
for i in range(74357):
  count += mbti_e_train['E'][i]
print(count)
# Out:
# 17027

# %%
y_e = mbti_e_train['E']
x_e_train = mbti_e_train['words']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfv_e = TfidfVectorizer(stop_words='english',analyzer = 'word',sublinear_tf=True,min_df=3).fit(list(x_e_train))
x_e_train_tfv = tfv_e.transform(x_e_train)

# %%
import xgboost as xgb
clf_e = xgb.XGBClassifier(max_depth=7,
                        n_estimators=200,
                        colsample_bytree=0.8,
                        subsample=0.8,
                        nthread=10,
                        learning_rate=0.1,
                        use_label_encoder=False,
                        eval_metric='logloss')
clf_e.fit(.tocsc(), )
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.8, eval_metric='logloss',
#               gamma=0, gpu_id=-1, importance_type='gain',
#               interaction_constraints='', learning_rate=0.1, max_delta_step=0,
#               max_depth=7, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=200, n_jobs=10,
#               nthread=10, num_parallel_tree=1, random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, subsample=0.8,
#               tree_method='exact', use_label_encoder=False,
#               validate_parameters=1, verbosity=None)

# %% [markdown]
# ## mbti_s

# %%
mbti_train['S'] = [0]*74357
mbti_train
# Out:
#        mbti                                              words  E  S
# 0      INTP  say process model list like subscriber channel...  0  0
# 1      INFJ  upon much manipulate retail finish like sacrif...  0  0
# 2      INFJ  fit yes certain bff social feel goal go know n...  0  0
# 3      INTJ  complete love within someone ideal joke solvea...  0  0
# 4      ENTJ  public strictly thing person x question person...  1  0
# ...     ...                                                ... .. ..
# 74352  INTP  get consequence process life back kind great b...  0  0
# 74353  ENFP  mundane really right vibe natural u conscious ...  1  0
# 74354  INFP  diva message remember practical lot absorb tel...  0  0
# 74355  INTJ  increase impressive group make recognize get a...  0  0
# 74356  ENTJ  restaurant negative entj resent people sing ma...  1  0
#
# [74357 rows x 4 columns]

# %%
for i in range(74357):
  if mbti_train['mbti'][i][1] == 'S':
    mbti_train['S'][i] = 1
mbti_train
# Out:
# <ipython-input-16-7c6d317735cf>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mbti_train['S'][i] = 1
#        mbti                                              words  E  S
# 0      INTP  say process model list like subscriber channel...  0  0
# 1      INFJ  upon much manipulate retail finish like sacrif...  0  0
# 2      INFJ  fit yes certain bff social feel goal go know n...  0  0
# 3      INTJ  complete love within someone ideal joke solvea...  0  0
# 4      ENTJ  public strictly thing person x question person...  1  0
# ...     ...                                                ... .. ..
# 74352  INTP  get consequence process life back kind great b...  0  0
# 74353  ENFP  mundane really right vibe natural u conscious ...  1  0
# ...

# %%
count = 0
for i in range(74357):
  count += mbti_train['S'][i]
print(count)
# Out:
# 5608

# %%
mbti_s_train = mbti_train.loc[:,['words','S']]

# %%
y_s = mbti_s_train['S']
x_s_train = mbti_s_train['words']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfv_s = TfidfVectorizer(stop_words='english',analyzer = 'word',sublinear_tf=True,min_df=3).fit(list(x_s_train))
x_s_train_tfv = tfv_s.transform(x_s_train)

# %%
import xgboost as xgb
clf_s = xgb.XGBClassifier(max_depth=7,
                        n_estimators=200,
                        colsample_bytree=0.8,
                        subsample=0.8,
                        nthread=10,
                        learning_rate=0.1,
                        use_label_encoder=False,
                        eval_metric='logloss')
clf_s.fit(.tocsc(), )
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.8, eval_metric='logloss',
#               gamma=0, gpu_id=-1, importance_type='gain',
#               interaction_constraints='', learning_rate=0.1, max_delta_step=0,
#               max_depth=7, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=200, n_jobs=10,
#               nthread=10, num_parallel_tree=1, random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, subsample=0.8,
#               tree_method='exact', use_label_encoder=False,
#               validate_parameters=1, verbosity=None)

# %% [markdown]
# ## mbti_t

# %%
mbti_train['T'] = [0]*74357
mbti_train
# Out:
#        mbti                                              words  E  S  T
# 0      INTP  say process model list like subscriber channel...  0  0  0
# 1      INFJ  upon much manipulate retail finish like sacrif...  0  0  0
# 2      INFJ  fit yes certain bff social feel goal go know n...  0  0  0
# 3      INTJ  complete love within someone ideal joke solvea...  0  0  0
# 4      ENTJ  public strictly thing person x question person...  1  0  0
# ...     ...                                                ... .. .. ..
# 74352  INTP  get consequence process life back kind great b...  0  0  0
# 74353  ENFP  mundane really right vibe natural u conscious ...  1  0  0
# 74354  INFP  diva message remember practical lot absorb tel...  0  0  0
# 74355  INTJ  increase impressive group make recognize get a...  0  0  0
# 74356  ENTJ  restaurant negative entj resent people sing ma...  1  0  0
#
# [74357 rows x 5 columns]

# %%
for i in range(74357):
  if mbti_train['mbti'][i][2] == 'T':
    mbti_train['T'][i] = 1
mbti_train
# Out:
# <ipython-input-25-e3ddb209843e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mbti_train['T'][i] = 1
#        mbti                                              words  E  S  T
# 0      INTP  say process model list like subscriber channel...  0  0  1
# 1      INFJ  upon much manipulate retail finish like sacrif...  0  0  0
# 2      INFJ  fit yes certain bff social feel goal go know n...  0  0  0
# 3      INTJ  complete love within someone ideal joke solvea...  0  0  1
# 4      ENTJ  public strictly thing person x question person...  1  0  1
# ...     ...                                                ... .. .. ..
# 74352  INTP  get consequence process life back kind great b...  0  0  1
# 74353  ENFP  mundane really right vibe natural u conscious ...  1  0  0
# ...

# %%
mbti_t_train = mbti_train.loc[:,['words','T']]

# %%
y_t = mbti_t_train['T']
x_t_train = mbti_t_train['words']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfv_t = TfidfVectorizer(stop_words='english',analyzer = 'word',sublinear_tf=True,min_df=3).fit(list(x_t_train))
x_t_train_tfv = tfv_t.transform(x_t_train)

# %%
import xgboost as xgb
clf_t = xgb.XGBClassifier(max_depth=7,
                        n_estimators=200,
                        colsample_bytree=0.8,
                        subsample=0.8,
                        nthread=10,
                        learning_rate=0.1,
                        use_label_encoder=False,
                        eval_metric='logloss')
clf_t.fit(.tocsc(),)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.8, eval_metric='logloss',
#               gamma=0, gpu_id=-1, importance_type='gain',
#               interaction_constraints='', learning_rate=0.1, max_delta_step=0,
#               max_depth=7, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=200, n_jobs=10,
#               nthread=10, num_parallel_tree=1, random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, subsample=0.8,
#               tree_method='exact', use_label_encoder=False,
#               validate_parameters=1, verbosity=None)

# %% [markdown]
# ## mbti_j

# %%
mbti_train['J'] = [0]*74357
mbti_train
# Out:
#        mbti                                              words  E  S  T  J
# 0      INTP  say process model list like subscriber channel...  0  0  1  0
# 1      INFJ  upon much manipulate retail finish like sacrif...  0  0  0  0
# 2      INFJ  fit yes certain bff social feel goal go know n...  0  0  0  0
# 3      INTJ  complete love within someone ideal joke solvea...  0  0  1  0
# 4      ENTJ  public strictly thing person x question person...  1  0  1  0
# ...     ...                                                ... .. .. .. ..
# 74352  INTP  get consequence process life back kind great b...  0  0  1  0
# 74353  ENFP  mundane really right vibe natural u conscious ...  1  0  0  0
# 74354  INFP  diva message remember practical lot absorb tel...  0  0  0  0
# 74355  INTJ  increase impressive group make recognize get a...  0  0  1  0
# 74356  ENTJ  restaurant negative entj resent people sing ma...  1  0  1  0
#
# [74357 rows x 6 columns]

# %%
for i in range(74357):
  if mbti_train['mbti'][i][3] == 'J':
    mbti_train['J'][i] = 1
mbti_train
# Out:
# <ipython-input-31-07d5689d1309>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mbti_train['J'][i] = 1
#        mbti                                              words  E  S  T  J
# 0      INTP  say process model list like subscriber channel...  0  0  1  0
# 1      INFJ  upon much manipulate retail finish like sacrif...  0  0  0  1
# 2      INFJ  fit yes certain bff social feel goal go know n...  0  0  0  1
# 3      INTJ  complete love within someone ideal joke solvea...  0  0  1  1
# 4      ENTJ  public strictly thing person x question person...  1  0  1  1
# ...     ...                                                ... .. .. .. ..
# 74352  INTP  get consequence process life back kind great b...  0  0  1  0
# 74353  ENFP  mundane really right vibe natural u conscious ...  1  0  0  0
# ...

# %%
mbti_j_train = mbti_train.loc[:,['words','J']]

# %%
y_j = mbti_j_train['J']
x_j_train = mbti_j_train['words']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfv_j = TfidfVectorizer(stop_words='english',analyzer = 'word',sublinear_tf=True,min_df=3).fit(list(x_j_train))
x_j_train_tfv = tfv_j.transform(x_j_train)

# %%
import xgboost as xgb
clf_j = xgb.XGBClassifier(max_depth=7,
                        n_estimators=200,
                        colsample_bytree=0.8,
                        subsample=0.8,
                        nthread=10,
                        learning_rate=0.1,
                        use_label_encoder=False,
                        eval_metric='logloss')
clf_j.fit(.tocsc(), )
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.8, eval_metric='logloss',
#               gamma=0, gpu_id=-1, importance_type='gain',
#               interaction_constraints='', learning_rate=0.1, max_delta_step=0,
#               max_depth=7, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=200, n_jobs=10,
#               nthread=10, num_parallel_tree=1, random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, subsample=0.8,
#               tree_method='exact', use_label_encoder=False,
#               validate_parameters=1, verbosity=None)

# %%
mbti_test.columns = ['words']
mbti_test
# Out:
#                                                   words
# 0     get accept ya bite well stop important open lo...
# 1     offer rebel something war people friend block ...
# 2     soulmates contradiction easy basic recurrence ...
# 3     run nature q test let sound sarcastically irri...
# 4     hour fast fast suspend see strict wampum eight...
# ...                                                 ...
# 9332  increase thing liquor analyze partner consider...
# 9333  senior vote wide shame learn talk problem broo...
# 9334  want relate top understand think read generate...
# 9335  alot set intjs soooo alone ease cherish anothe...
# 9336  absent absolutely test recourse belong pe get ...
#
# [9337 rows x 1 columns]

# %% [markdown]
# ## bmti_test

# %%
mbti_e_test_tfv = tfv_e.transform(mbti_test['words'])
mbti_s_test_tfv = tfv_s.transform(mbti_test['words'])
mbti_t_test_tfv = tfv_t.transform(mbti_test['words'])
mbti_j_test_tfv = tfv_j.transform(mbti_test['words'])

# %%
predictions_e = clf_e.predict(.tocsc())

# %%
predictions_s = clf_s.predict(.tocsc())

# %%
predictions_t = clf_t.predict(.tocsc())

# %%
predictions_j = clf_j.predict(.tocsc())

# %%
len(predictions_t)
# Out:
# 9337

# %%
count=0
for i in range(9337):
    if predictions_t[i] == 1:
        count+=1
print(count)
# Out:
# 6220

# %%
li = ['1']*9337
for i in range(9337):
  if predictions_e[i] == 1:
    li[i] = 'E'
  elif predictions_e[i] == 0:
    li[i] = 'I'
  
  if predictions_s[i] == 1:
    li[i] += 'S'
  elif predictions_s[i] == 0:
    li[i] += 'N'

  if predictions_t[i] == 1: 
    li[i] += 'T'
  elif predictions_t[i] == 0:
    li[i] += 'F'

  if predictions_j[i] == 1:
    li[i] += 'J'
  elif predictions_j[i] == 0:
    li[i] += 'P'
li
# Out:
# ['ENFP',
#  'ENTP',
#  'INTJ',
#  'INTJ',
#  'INTJ',
#  'INTJ',
#  'INFP',
#  'INFJ',
#  'ENFP',
#  'INFJ',
#  'ENTP',
#  'INTP',
#  'ENTP',
#  'INFP',
#  'INTP',
#  'INFJ',
#  'INTP',
#  'INFP',
#  'INTJ',
#  'INTP',
#  'INFP',
#  'INTJ',
#  'INTP',
#  'INTP',
#  'ESTP',
#  'INTJ',
#  'INFJ',
#  'INTP',
#  'INTJ',
#  'INFP',
#  'INTJ',
#  'INFJ',
#  'INFP',
#  'INTJ',
#  'INTP',
#  'ENFP',
#  'ENFP',
#  'INTP',
#  'INFP',
#  'INTP',
#  'ENFP',
#  'INFJ',
#  'INTP',
#  'ENTP',
#  'ENTP',
#  'INTP',
#  'INTJ',
#  'INTJ',
#  'INFJ',
#  'INFJ',
#  'ESTP',
#  'ISTP',
#  'INTJ',
#  'INFP',
#  'ISTP',
#  'INTP',
#  'INTJ',
#  'INTJ',
#  'INFP',
#  'INTP',
#  'ENFP',
#  'INTJ',
#  'INFP',
#  'INTP',
#  'INTJ',
#  'INFP',
#  'INTJ',
#  'INTP',
#  'INTJ',
#  'ENTP',
#  'INTP',
#  'INTP',
#  'ENFP',
#  'ESTP',
#  'INTJ',
#  'INTJ',
#  'INFP',
#  'INFP',
#  'ENFP',
#  'INTJ',
#  'INTJ',
#  'INTP',
#  'INFJ',
#  'INTP',
#  'INFP',
#  'INTP',
#  'ENTJ',
#  'INFJ',
#  'INTP',
#  'INFP',
# ...

# %%
df = pd.DataFrame(li)

# %%
df
# Out:
#          0
# 0     ENFP
# 1     ENTP
# 2     INTJ
# 3     INTJ
# 4     INTJ
# ...    ...
# 9332  ENTP
# 9333  INTJ
# 9334  INTP
# 9335  INTP
# 9336  INTP
#
# [9337 rows x 1 columns]

# %%
df.to_csv("Final_result_team22.csv", header=None, index=False)
